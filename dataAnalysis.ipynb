# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from datetime import date, timedelta
import math

# %%
traindata = pd.read_csv('./dataset/train.csv')

# %%
traindata.shape
# Out:
# (4368, 21)

# %%
traindata.head()
# Out:
#                  approveddate                creationdate  \
# 0  2017-07-25 08:22:56.000000  2017-07-25 07:22:47.000000
# 1  2017-07-05 17:04:41.000000  2017-07-05 16:04:18.000000
# 2  2017-07-06 14:52:57.000000  2017-07-06 13:52:51.000000
# 3  2017-07-27 19:00:41.000000  2017-07-27 18:00:35.000000
# 4  2017-07-03 23:42:45.000000  2017-07-03 22:42:39.000000
#
#                          customerid  loanamount  loannumber referredby  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     30000.0          12        NaN
# 1  8a85886e54beabf90154c0a29ae757c0     15000.0           2        NaN
# 2  8a8588f35438fe12015444567666018e     20000.0           7        NaN
# 3  8a85890754145ace015429211b513e16     10000.0           3        NaN
# 4  8a858970548359cc0154883481981866     40000.0           9        NaN
#
#    systemloanid  termdays  totaldue                   birthdate  \
# 0     301994762        30   34500.0  1972-01-15 00:00:00.000000
# 1     301965204        30   17250.0  1985-08-23 00:00:00.000000
# 2     301966580        15   22250.0  1984-09-18 00:00:00.000000
# 3     301999343        15   11500.0  1977-10-10 00:00:00.000000
# 4     301962360        30   44000.0  1986-09-07 00:00:00.000000
#
#        ...       longitude_gps  latitude_gps  bank_name_clients  \
# 0      ...            3.432010      6.433055       Diamond Bank
# 1      ...            3.885298      7.320700            GT Bank
# 2      ...           11.139350     10.292041            EcoBank
# 3      ...            3.985770      7.491708         First Bank
# 4      ...            7.457913      9.076574            GT Bank
#
#   bank_branch_clients employment_status_clients level_of_education_clients  \
# 0                 NaN                 Permanent              Post-Graduate
# 1        DUGBE,IBADAN                 Permanent                   Graduate
# 2                 NaN                 Permanent                        NaN
# 3                 NaN                 Permanent                        NaN
# 4                 NaN                 Permanent                    Primary
#
#   avg_loanamount  avg_totaldue  repaymentdays  good_bad_flag
# 0   18181.818182  22081.818182           10.0           Good
# 1       0.000000      0.000000            0.0           Good
# 2   10000.000000  11750.000000           -5.0           Good
# 3   10000.000000  12250.000000          -15.0           Good
# 4   18750.000000  23550.000000           25.0           Good
#
# [5 rows x 21 columns]

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4368 entries, 0 to 4367
# Data columns (total 21 columns):
# approveddate                  4368 non-null object
# creationdate                  4368 non-null object
# customerid                    4368 non-null object
# loanamount                    4368 non-null float64
# loannumber                    4368 non-null int64
# referredby                    587 non-null object
# systemloanid                  4368 non-null int64
# termdays                      4368 non-null int64
# totaldue                      4368 non-null float64
# birthdate                     4368 non-null object
# bank_account_type             4368 non-null object
# longitude_gps                 4368 non-null float64
# latitude_gps                  4368 non-null float64
# bank_name_clients             4368 non-null object
# bank_branch_clients           43 non-null object
# employment_status_clients     3711 non-null object
# level_of_education_clients    605 non-null object
# avg_loanamount                4368 non-null float64
# avg_totaldue                  4368 non-null float64
# repaymentdays                 4368 non-null float64
# good_bad_flag                 4368 non-null object
# dtypes: float64(7), int64(3), object(11)
# memory usage: 716.7+ KB

# %% [markdown]
# ### ---- Feature creation and processing ---

# %% [markdown]
# ### 1- approveddate and creationdate are same for almost all records, will not carry much information - we can remove them

# %% [markdown]
# ### 2 - Finding Impact of loanamount on class label

# %%
pd.crosstab(traindata.loanamount,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# loanamount
# 10000.0        655  1807
# 15000.0         11    71
# 20000.0        127   653
# 25000.0          4    27
# 30000.0         96   488
# 35000.0          1     9
# 40000.0         46   287
# 45000.0          0     1
# 50000.0         11    66
# 60000.0          1     7

# %% [markdown]
# #### Most of the bad loan are for 10000, we can create three ordinal values 1 for <= 20000 and 2 for <= 40000 and 3 for <=60000

# %%
def getLoanAmtRank(loanAmt):
    if( loanAmt <= 20000 ):
        return 1
    elif( loanAmt <= 40000):
        return 2
    else:
        return 3

# %%
traindata['rankloanamt'] = traindata['loanamount'].apply(getLoanAmtRank)

# %%
pd.crosstab(traindata.rankloanamt,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# rankloanamt
# 1              793  2531
# 2              147   811
# 3               12    74

# %% [markdown]
# ### 3 - Finding impact of loan number on class label

# %%
pd.crosstab(traindata.loannumber,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# loannumber
# 2              347  1046
# 3              179   491
# 4              111   332
# 5               52   274
# 6               56   191
# 7               41   211
# 8               37   183
# 9               30   150
# 10              28   163
# 11              16    97
# 12              22    87
# 13              11    67
# 14              10    40
# 15               3    39
# 16               3    17
# 17               4    11
# 18               1     2
# 19               0     6
# 20               0     2
# 21               0     1
# 22               1     4
# 23               0     1
# 27               0     1

# %% [markdown]
# #### Loan number > 18 are pure. We can divide this column into two ordinal values 1 for <= 18 and 2 for > 18

# %%
def getLoanNumberRank(loannumber):
    if( loannumber < 18 ):
        return 1
    else:
        return 2

# %%
traindata['rankloannum'] = traindata['loannumber'].apply(getLoanNumberRank)

# %%
pd.crosstab(traindata.rankloannum, traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# rankloannum
# 1              950  3399
# 2                2    17

# %% [markdown]
# ### 4 - Impact of referredby on class label

# %%
pd.crosstab(traindata.referredby.isnull(),traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# referredby
# False          134   453
# True           818  2963

# %% [markdown]
# #### There is relation, if loan is through rferral then most of the loans are bad, we can create binary attribute for this

# %% [markdown]
# #### if referred then 1 else 0

# %%
traindata['referredby'] = traindata['referredby'].fillna(0)

# %%
def isReferred(reffered):
    if( reffered == 0 ):
        return 0
    else:
        return 1

# %%
traindata['isreffered'] = traindata['referredby'].apply(isReferred)

# %%
pd.crosstab(traindata.isreffered,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# isreffered
# 0              818  2963
# 1              134   453

# %% [markdown]
# ### 5 - Impact of systemloanid on class label

# %%
traindata['systemloanid'].unique().shape
# Out:
# (4368,)

# %% [markdown]
# #### This is unique number and it has no impact on class label and we can drop this column

# %% [markdown]
# ### 6 - Impact of termdays on class label

# %%
pd.crosstab(traindata.termdays,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# termdays
# 15             208   711
# 30             673  2456
# 60              65   223
# 90               6    26

# %% [markdown]
# #### There is no clear relation here, we can let this categorical data as it is

# %% [markdown]
# ### 7 - Impact of totaldue on class label

# %% [markdown]
# #### totaldue - loanamount can give interest amount - we can find impact of interest amount on class label

# %%
traindata['interest'] = traindata['totaldue'] - traindata['loanamount']

# %%
traindata.head()
# Out:
#                  approveddate                creationdate  \
# 0  2017-07-25 08:22:56.000000  2017-07-25 07:22:47.000000
# 1  2017-07-05 17:04:41.000000  2017-07-05 16:04:18.000000
# 2  2017-07-06 14:52:57.000000  2017-07-06 13:52:51.000000
# 3  2017-07-27 19:00:41.000000  2017-07-27 18:00:35.000000
# 4  2017-07-03 23:42:45.000000  2017-07-03 22:42:39.000000
#
#                          customerid  loanamount  loannumber referredby  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     30000.0          12        NaN
# 1  8a85886e54beabf90154c0a29ae757c0     15000.0           2        NaN
# 2  8a8588f35438fe12015444567666018e     20000.0           7        NaN
# 3  8a85890754145ace015429211b513e16     10000.0           3        NaN
# 4  8a858970548359cc0154883481981866     40000.0           9        NaN
#
#    systemloanid  termdays  totaldue                   birthdate    ...     \
# 0     301994762        30   34500.0  1972-01-15 00:00:00.000000    ...
# 1     301965204        30   17250.0  1985-08-23 00:00:00.000000    ...
# 2     301966580        15   22250.0  1984-09-18 00:00:00.000000    ...
# 3     301999343        15   11500.0  1977-10-10 00:00:00.000000    ...
# 4     301962360        30   44000.0  1986-09-07 00:00:00.000000    ...
#
#   latitude_gps  bank_name_clients  bank_branch_clients  \
# 0     6.433055       Diamond Bank                  NaN
# 1     7.320700            GT Bank         DUGBE,IBADAN
# 2    10.292041            EcoBank                  NaN
# 3     7.491708         First Bank                  NaN
# 4     9.076574            GT Bank                  NaN
#
#   employment_status_clients level_of_education_clients avg_loanamount  \
# 0                 Permanent              Post-Graduate   18181.818182
# 1                 Permanent                   Graduate       0.000000
# 2                 Permanent                        NaN   10000.000000
# 3                 Permanent                        NaN   10000.000000
# 4                 Permanent                    Primary   18750.000000
#
#    avg_totaldue  repaymentdays  good_bad_flag  interest
# 0  22081.818182           10.0           Good    4500.0
# 1      0.000000            0.0           Good    2250.0
# 2  11750.000000           -5.0           Good    2250.0
# 3  12250.000000          -15.0           Good    1500.0
# 4  23550.000000           25.0           Good    4000.0
#
# [5 rows x 22 columns]

# %%
pd.crosstab(traindata.interest,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# interest
# 0.0              0     1
# 250.0            0     1
# 500.0            0     3
# 750.0            0    14
# 1000.0           0    19
# 1125.0           2    37
# 1500.0         174   555
# 1687.5           2    16
# 1750.0           1     2
# 2000.0           0    13
# 2250.0          32   135
# 2500.0           4    56
# 2700.0           0     2
# 3000.0         479  1204
# 3375.0           8    31
# 3500.0           1    10
# 3750.0           4    14
# 3999.9           0     4
# 4000.0          22   198
# 4500.0         152   854
# 5000.0           5    11
# 5400.0           0     2
# 6000.0           2     8
# 7000.0           1     2
# 7000.5           0     1
# 7500.0           5    22
# 8000.0          24    92
# 8100.0           1     3
# 8500.2           0     3
# 9000.0          33   103

# %% [markdown]
# #### No clear relation for this continuous attribute. We can drop totaldue and interest

# %% [markdown]
# ### 8 - Impact of birthdate (age) on class label

# %% [markdown]
# #### age is loan approve date - birth date

# %%
def createDate(strDate):
    strDate = strDate[:10]
    s = strDate.split('-')
    s = [int(y) for y in s]  
    s = date(s[0], s[1], s[2])
    return s

# %%
def getAgeInYears(strDays):
    strDays = str(strDays)
    s = strDays.split(" ")
    return math.floor(int(s[0])/365)

# %%
traindata['approveddate'] = traindata['approveddate'].apply(createDate)

# %%
traindata['birthdate'] = traindata['birthdate'].apply(createDate)

# %%
traindata['age'] = traindata['approveddate'] - traindata['birthdate']

# %%
traindata.head()
# Out:
#   approveddate                creationdate                        customerid  \
# 0   2017-07-25  2017-07-25 07:22:47.000000  8a2a81a74ce8c05d014cfb32a0da1049
# 1   2017-07-05  2017-07-05 16:04:18.000000  8a85886e54beabf90154c0a29ae757c0
# 2   2017-07-06  2017-07-06 13:52:51.000000  8a8588f35438fe12015444567666018e
# 3   2017-07-27  2017-07-27 18:00:35.000000  8a85890754145ace015429211b513e16
# 4   2017-07-03  2017-07-03 22:42:39.000000  8a858970548359cc0154883481981866
#
#    loanamount  loannumber referredby  systemloanid  termdays  totaldue  \
# 0     30000.0          12        NaN     301994762        30   34500.0
# 1     15000.0           2        NaN     301965204        30   17250.0
# 2     20000.0           7        NaN     301966580        15   22250.0
# 3     10000.0           3        NaN     301999343        15   11500.0
# 4     40000.0           9        NaN     301962360        30   44000.0
#
#     birthdate    ...     bank_name_clients  bank_branch_clients  \
# 0  1972-01-15    ...          Diamond Bank                  NaN
# 1  1985-08-23    ...               GT Bank         DUGBE,IBADAN
# 2  1984-09-18    ...               EcoBank                  NaN
# 3  1977-10-10    ...            First Bank                  NaN
# 4  1986-09-07    ...               GT Bank                  NaN
#
#    employment_status_clients level_of_education_clients avg_loanamount  \
# 0                  Permanent              Post-Graduate   18181.818182
# 1                  Permanent                   Graduate       0.000000
# 2                  Permanent                        NaN   10000.000000
# 3                  Permanent                        NaN   10000.000000
# 4                  Permanent                    Primary   18750.000000
#
#    avg_totaldue repaymentdays  good_bad_flag  interest        age
# 0  22081.818182          10.0           Good    4500.0 16628 days
# 1      0.000000           0.0           Good    2250.0 11639 days
# 2  11750.000000          -5.0           Good    2250.0 11979 days
# 3  12250.000000         -15.0           Good    1500.0 14535 days
# 4  23550.000000          25.0           Good    4000.0 11257 days
#
# [5 rows x 23 columns]

# %%
traindata['age'] = traindata['age'].apply(getAgeInYears)

# %%
traindata.head()
# Out:
#   approveddate                creationdate                        customerid  \
# 0   2017-07-25  2017-07-25 07:22:47.000000  8a2a81a74ce8c05d014cfb32a0da1049
# 1   2017-07-05  2017-07-05 16:04:18.000000  8a85886e54beabf90154c0a29ae757c0
# 2   2017-07-06  2017-07-06 13:52:51.000000  8a8588f35438fe12015444567666018e
# 3   2017-07-27  2017-07-27 18:00:35.000000  8a85890754145ace015429211b513e16
# 4   2017-07-03  2017-07-03 22:42:39.000000  8a858970548359cc0154883481981866
#
#    loanamount  loannumber referredby  systemloanid  termdays  totaldue  \
# 0     30000.0          12        NaN     301994762        30   34500.0
# 1     15000.0           2        NaN     301965204        30   17250.0
# 2     20000.0           7        NaN     301966580        15   22250.0
# 3     10000.0           3        NaN     301999343        15   11500.0
# 4     40000.0           9        NaN     301962360        30   44000.0
#
#     birthdate ...  bank_name_clients  bank_branch_clients  \
# 0  1972-01-15 ...       Diamond Bank                  NaN
# 1  1985-08-23 ...            GT Bank         DUGBE,IBADAN
# 2  1984-09-18 ...            EcoBank                  NaN
# 3  1977-10-10 ...         First Bank                  NaN
# 4  1986-09-07 ...            GT Bank                  NaN
#
#    employment_status_clients level_of_education_clients avg_loanamount  \
# 0                  Permanent              Post-Graduate   18181.818182
# 1                  Permanent                   Graduate       0.000000
# 2                  Permanent                        NaN   10000.000000
# 3                  Permanent                        NaN   10000.000000
# 4                  Permanent                    Primary   18750.000000
#
#    avg_totaldue repaymentdays  good_bad_flag  interest  age
# 0  22081.818182          10.0           Good    4500.0   45
# 1      0.000000           0.0           Good    2250.0   31
# 2  11750.000000          -5.0           Good    2250.0   32
# 3  12250.000000         -15.0           Good    1500.0   39
# 4  23550.000000          25.0           Good    4000.0   30
#
# [5 rows x 23 columns]

# %%
pd.crosstab(traindata.age,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# age
# 21               6    17
# 22              30    42
# 23              26    83
# 24              42   112
# 25              54   123
# 26              45   130
# 27              56   163
# 28              60   212
# 29              49   227
# 30              68   212
# 31              62   254
# 32              55   244
# 33              63   226
# 34              41   213
# 35              32   182
# 36              48   160
# 37              39   138
# 38              34   128
# 39              20    98
# 40              19    77
# 41              26    67
# 42              17    68
# 43              15    52
# 44              12    30
# 45               8    33
# 46               4    15
# 47              11    24
# 48               0    19
# 49               4    16
# 50               0    11
# 51               2    15
# 52               2     7
# 53               2     6
# 54               0     6
# 55               0     6

# %% [markdown]
# #### old adult > 45 have more pure values. We can divide this into two categorical values - 1 for <= 45 and 2 for > 45

# %%
def getAgeRank(age):
    if( age <= 45 ):
        return 1
    else:
        return 2

# %%
traindata['agerank'] = traindata['age'].apply(getAgeRank)

# %%
pd.crosstab(traindata.agerank,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# agerank
# 1              927  3291
# 2               25   125

# %% [markdown]
# ### 9 - Impact of bank account type

# %%
pd.crosstab(traindata.bank_account_type,traindata.good_bad_flag)
# Out:
# good_bad_flag      Bad  Good
# bank_account_type
# Current              7    57
# Other              131   756
# Savings            814  2603

# %% [markdown]
# #### we can use this categorical column as it is

# %% [markdown]
# ### 10 - impact of longitude_gps & latitude_gps  on class label

# %%
pd.crosstab(traindata.longitude_gps,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# longitude_gps
# -149.033700      1     0
# -118.247009      0     1
# -117.822509      1     0
# -98.495394       1     0
# -95.737058       0     1
# -95.693698       0     1
# -95.609958       0     1
# -95.337212       0     1
# -92.391699       1     0
# -84.637253       0     1
# -84.378662       0     1
# -77.441691       0     1
# -76.580068       0     1
# -73.985657       1     0
# -73.839414       0     1
# -15.421508       0     1
# -7.239446        0     1
# -4.002155        0     1
# -3.977151        0     1
# -3.805697        0     1
# -3.560050        1     0
# -2.979950        1     0
# -0.117477        0     1
# -0.093080        0     1
# -0.065909        1     0
#  2.444809        1     0
#  2.446472        0     1
#  2.553592        1     0
#  2.748630        0     1
#  2.749420        0     1
# ...            ...   ...
#  11.141082       0     1
#  11.178342       1     0
#  11.299289       0     1
#  11.344892       0     1
#  11.947411       0     1
#  12.035570       0     1
#  12.044160       1     0
#  12.055583       0     1
#  12.410300       0     1
#  12.421220       1     0
#  12.436271       0     1
#  12.436804       0     1
#  12.445369       0     1
#  12.455868       1     0
#  12.473708       0     1
#  12.480517       0     1
#  13.124637       0     1
#  13.154806       0     1
#  13.163749       0     1
#  13.185569       0     1
#  14.130563       0     1
#  39.815590       0     1
#  55.277907       1     0
#  55.296435       1     0
#  56.342638       0     1
#  94.676765       0     1
#  100.077895      0     1
#  100.619249      0     1
#  116.296503      1     0
#  151.209290      0     1
#
# [4138 rows x 2 columns]

# %%
pd.crosstab(traindata.latitude_gps,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# latitude_gps
# -33.868818       0     1
# -8.348493        1     0
#  4.384586        0     1
#  4.400570        0     1
#  4.401684        1     0
#  4.417736        0     1
#  4.432237        0     1
#  4.438133        1     0
#  4.505915        0     1
#  4.545390        0     1
#  4.622279        0     1
#  4.623379        0     1
#  4.636685        0     1
#  4.636914        0     1
#  4.640339        0     1
#  4.643889        0     1
#  4.645819        0     1
#  4.650432        0     1
#  4.679267        0     1
#  4.714542        0     1
#  4.717945        0     1
#  4.720982        0     1
#  4.732513        1     0
#  4.732979        0     1
#  4.735293        1     0
#  4.753053        1     0
#  4.753120        0     1
#  4.754407        1     0
#  4.756943        0     1
#  4.759162        0     1
# ...            ...   ...
#  13.046228       1     0
#  13.066239       0     1
#  13.746128       0     1
#  13.988297       1     0
#  21.428970       0     1
#  25.199406       1     0
#  25.256658       1     0
#  25.351997       0     1
#  28.116417       0     1
#  29.425541       1     0
#  29.784622       0     1
#  29.862125       0     1
#  29.935458       0     1
#  33.577121       0     1
#  33.883619       1     0
#  34.064419       0     1
#  34.550103       1     0
#  37.042246       0     1
#  39.322143       0     1
#  39.356038       0     1
#  39.518227       0     1
#  40.048760       1     0
#  40.748516       1     0
#  40.895322       0     1
#  51.916283       0     1
#  54.593071       1     0
#  54.998841       0     1
#  55.311599       0     1
#  56.464013       1     0
#  71.228069       0     1
#
# [4345 rows x 2 columns]

# %% [markdown]
# #### both these continous attribute doesnt carry much information in relation with class label

# %% [markdown]
# ### 11 - impact of bank_name_clients on class label

# %%
pd.crosstab(traindata.bank_name_clients,traindata.good_bad_flag)
# Out:
# good_bad_flag       Bad  Good
# bank_name_clients
# Access Bank         101   328
# Diamond Bank         42   256
# EcoBank              41   117
# FCMB                 29    89
# Fidelity Bank        27    76
# First Bank          133   442
# GT Bank             348  1256
# Heritage Bank         3    19
# Keystone Bank         4    16
# Skye Bank            32    79
# Stanbic IBTC         26   128
# Standard Chartered    1    16
# Sterling Bank        19    33
# UBA                  75   268
# Union Bank            5    18
# Unity Bank            1     5
# Wema Bank             2    23
# Zenith Bank          63   247

# %% [markdown]
# #### data is spread uniformally across all bank - no much impact on claa label

# %% [markdown]
# ### 12 - Impact of bank branch client on class label

# %%
pd.crosstab(traindata.bank_branch_clients,traindata.good_bad_flag)
# Out:
# good_bad_flag                                       Bad  Good
# bank_branch_clients
#  IDI - ORO MUSHIN                                     1     0
# 17, SANUSI FAFUNWA STREET, VICTORIA ISLAND, LAGOS     0     1
# 3, OBA AKRAN                                          0     1
# 40,SAPELE ROAD ,OPPOSITE DUMAZ JUNCTION BENIN C...    0     1
# ABEOKUTA                                              0     1
# ABULE EGBA                                            0     1
# ACCESS BANK PLC, CHALLENGE ROUNDABOUT IBADAN, O...    1     0
# ADEOLA HOPEWELL                                       0     1
# ADETOKUNBO ADEMOLA                                    0     1
# AJOSE ADEOGUN                                         0     1
# AKOKA                                                 1     0
# AKURE BRANCH                                          1     0
# AKUTE                                                 1     0
# AKUTE,LAGOS.                                          0     1
# APAPA                                                 0     2
# BOSSO ROAD, MINNA                                     0     1
# DUGBE,IBADAN                                          0     1
# GBAGADA                                               1     0
# HEAD OFFICE                                           0     1
# IKEJA                                                 0     1
# IWO ROAD BRANCH                                       0     1
# LAGOS                                                 0     1
# LEKKI EPE                                             0     1
# MAFOLUKU                                              0     1
# MUSHIN BRANCH                                         0     1
# OAU ILE IFE                                           0     1
# OBA ADEBIMPE                                          0     1
# OBA AKRAN                                             0     2
# OBA AKRAN BERGER PAINT                                0     1
# OGBA                                                  1     2
# OGUDU, OJOTA                                          0     1
# OJUELEGBA                                             1     0
# PLOT 999C DANMOLE STREET, ADEOLA ODEKU, VICTORI...    0     1
# RCCG CAMP                                             0     1
# RING ROAD                                             0     1
# STERLING BANK PLC 102, IJU ROAD, IFAKO BRANCH         1     0
# TINCAN                                                0     1
# TRANS AMADI                                           0     1
# WHARF ROAD, APAPA                                     1     0

# %% [markdown]
# #### we can remove this attribute as there is very less data available

# %% [markdown]
# ### 13 - Impact of employment_status_clients on class label

# %%
traindata['employment_status_clients'].isnull().sum()
# Out:
# 657

# %% [markdown]
# ### Fill empty with next valid observation

# %%
traindata['employment_status_clients'] = traindata['employment_status_clients'].fillna(method='bfill')

# %%
pd.crosstab(traindata.employment_status_clients,traindata.good_bad_flag)
# Out:
# good_bad_flag              Bad  Good
# employment_status_clients
# Contract                     1     3
# Permanent                  792  2896
# Retired                      4     6
# Self-Employed               87   339
# Student                     53   117
# Unemployed                  14    55

# %% [markdown]
# #### we can use these categorical values as it is

# %% [markdown]
# ### 14 - Impact of level_of_education_clients on class label

# %%
traindata['level_of_education_clients'].isnull().sum()
# Out:
# 3763

# %% [markdown]
# #### there are many missing values - we can remove this attribute

# %% [markdown]
# ### 15 - Impact of avg_loanamount and avg_totaldue

# %%
pd.crosstab(traindata.avg_loanamount,traindata.good_bad_flag)
# Out:
# good_bad_flag   Bad  Good
# avg_loanamount
# 0.000000          3     6
# 5000.000000       0     1
# 7500.000000       0     1
# 8000.000000       0     1
# 8333.333333       0     2
# 8750.000000       0     2
# 9000.000000       0     4
# 9166.666667       0     1
# 9250.000000       0     1
# 9333.333333       0     1
# 9375.000000       0     1
# 9500.000000       2     3
# 9666.666667       0     1
# 9777.777778       1     0
# 10000.000000    695  1980
# 10333.333333      1     0
# 10625.000000      0     1
# 10714.285714      0     2
# 10750.000000      0     1
# 10833.333333      0     2
# 10909.090909      1     1
# 11000.000000      1     6
# 11111.111111      0     5
# 11142.857143      1     0
# 11250.000000      1    24
# 11363.636364      2     1
# 11428.571429      1     8
# 11500.000000      0     1
# 11666.666667      4    22
# 11875.000000      1     3
# ...             ...   ...
# 28461.538462      0     2
# 28571.428571      1     2
# 28666.666667      0     1
# 28846.153846      0     1
# 29000.000000      0     1
# 29090.909091      0     1
# 29166.666667      0     4
# 29230.769231      0     3
# 29285.714286      0     2
# 29333.333333      0     1
# 29375.000000      0     1
# 29642.857143      0     1
# 29666.666667      0     1
# 30000.000000      1    10
# 30277.777778      0     1
# 30454.545455      0     1
# 30476.190476      0     1
# 30666.666667      1     0
# 30769.230769      0     1
# 30928.571429      0     1
# 31666.666667      0     1
# 31700.000000      0     1
# 31875.000000      1     0
# 31944.444444      0     1
# 32142.857143      0     1
# 32500.000000      1     1
# 33437.500000      0     1
# 33571.428571      0     2
# 33888.888889      0     1
# 36666.666667      1     0
#
# [262 rows x 2 columns]

# %%
def getAvgLoanamtRank(avgLoanamt):
    if( avgLoanamt < 10000 ):
        return 1
    elif( avgLoanamt < 20000):
        return 2
    elif( avgLoanamt < 30000):
        return 3
    else:
        return 4

# %%
traindata['avgloanamtrank'] = traindata['avg_loanamount'].apply(getAvgLoanamtRank)

# %%
pd.crosstab(traindata.avgloanamtrank,traindata.good_bad_flag)
# Out:
# good_bad_flag   Bad  Good
# avgloanamtrank
# 1                 6    25
# 2               875  2945
# 3                66   422
# 4                 5    24

# %%
traindata['avg_interest'] = traindata['avg_totaldue'] - traindata['avg_loanamount']

# %%
def getInt(num):
    return math.floor(num)

# %%
traindata['avg_interest'] = traindata['avg_interest'].apply(getInt)

# %%
pd.crosstab(traindata.avg_interest,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# avg_interest
# 0                3     6
# 750              0     1
# 1125             0     1
# 1225             0     1
# 1241             0     1
# 1250             0     2
# 1312             0     3
# 1332             0     1
# 1333             1     1
# 1339             0     1
# 1350             0     2
# 1406             2     2
# 1462             1     2
# 1472             0     1
# 1500           202   593
# 1531             1     0
# 1537             0     1
# 1546             1     1
# 1554             0     1
# 1557             0     1
# 1559             0     1
# 1560             0     1
# 1562             0     4
# 1566             0     2
# 1570             0     1
# 1575             0     3
# 1577             0     1
# 1582             0     1
# 1593             0     1
# 1621             0     1
# ...            ...   ...
# 5225             1     0
# 5227             1     0
# 5244             0     1
# 5255             0     1
# 5271             1     0
# 5281             1     0
# 5300             0     1
# 5318             0     2
# 5333             1     2
# 5341             0     1
# 5377             0     1
# 5400             0     1
# 5437             0     1
# 5474             0     1
# 5475             1     0
# 5530             0     1
# 5533             0     1
# 5536             0     1
# 5570             1     0
# 5590             0     1
# 5603             0     1
# 5675             1     0
# 5680             1     0
# 5740             1     0
# 5750             0     1
# 5780             0     1
# 5912             0     1
# 6030             0     1
# 6750             0     1
# 9000             1     1
#
# [889 rows x 2 columns]

# %% [markdown]
# #### Try creating four categories

# %%
def getInterestRank(avgInterest):
    if( avgInterest < 2500 ):
        return 1
    elif( avgInterest < 5000):
        return 2
    elif( avgInterest < 7500):
        return 3
    else:
        return 4

# %%
traindata['avginterestrank'] = traindata['avg_interest'].apply(getInterestRank)

# %%
pd.crosstab(traindata.avginterestrank,traindata.good_bad_flag)
# Out:
# good_bad_flag    Bad  Good
# avginterestrank
# 1                341  1102
# 2                596  2273
# 3                 14    40
# 4                  1     1

# %% [markdown]
# #### Not much information with this attribute - We can drop avg_interest, avginterestrank

# %% [markdown]
# ### 16 - Impact of repaymentdays on class label

# %%
pd.crosstab(traindata.repaymentdays,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# repaymentdays
# -363.0           1     0
# -285.0           1     0
# -227.0           1     0
# -191.0           0     1
# -171.0           0     1
# -164.0           1     0
# -162.0           1     0
# -160.0           0     1
# -152.0           0     1
# -142.0           0     1
# -136.0           0     1
# -133.0           1     0
# -128.0           0     1
# -127.0           0     1
# -121.0           1     0
# -115.0           1     0
# -111.0           1     0
# -109.0           1     0
# -108.0           0     1
# -107.0           1     0
# -105.0           0     1
# -98.0            1     0
# -91.0            0     1
# -90.0            1     0
# -89.0            1     0
# -88.0            0     2
# -87.0            1     0
# -86.0            0     1
# -83.0            0     1
# -82.0            0     1
# ...            ...   ...
#  115.0           0     4
#  117.0           0     1
#  119.0           1     0
#  120.0           0     1
#  121.0           0     2
#  123.0           0     1
#  126.0           1     0
#  129.0           0     1
#  131.0           0     1
#  132.0           0     2
#  137.0           0     1
#  138.0           0     1
#  140.0           0     1
#  142.0           0     1
#  143.0           0     3
#  146.0           0     1
#  147.0           0     2
#  149.0           0     1
#  151.0           0     1
#  153.0           1     0
#  154.0           0     1
#  155.0           0     1
#  162.0           1     1
#  163.0           0     1
#  186.0           0     1
#  190.0           0     1
#  210.0           1     0
#  242.0           0     1
#  359.0           0     1
#  386.0           1     0
#
# [243 rows x 2 columns]

# %% [markdown]
# #### repayment days show impact on class label. negative repayment days have more bad loan

# %% [markdown]
# #### we can split range (-350 to 400) into 4 categorical rank 1 < -200, 2 < 0, 3 < 200, 4 < 400

# %%
def getRepaymetRank(repaymentDays):
    if( repaymentDays < -200 ):
        return 1
    elif( repaymentDays < 0):
        return 2
    elif( repaymentDays < 200):
        return 3
    else:
        return 4

# %%
traindata['repaymentrank'] = traindata['repaymentdays'].apply(getRepaymetRank)

# %%
pd.crosstab(traindata.repaymentrank,traindata.good_bad_flag)
# Out:
# good_bad_flag  Bad  Good
# repaymentrank
# 1                3     0
# 2              381   518
# 3              566  2896
# 4                2     2

# %% [markdown]
# #### repaymentrank is pure for rank 1, we can drop repaymentdays

# %%
traindata.head()
# Out:
#   approveddate                creationdate                        customerid  \
# 0   2017-07-25  2017-07-25 07:22:47.000000  8a2a81a74ce8c05d014cfb32a0da1049
# 1   2017-07-05  2017-07-05 16:04:18.000000  8a85886e54beabf90154c0a29ae757c0
# 2   2017-07-06  2017-07-06 13:52:51.000000  8a8588f35438fe12015444567666018e
# 3   2017-07-27  2017-07-27 18:00:35.000000  8a85890754145ace015429211b513e16
# 4   2017-07-03  2017-07-03 22:42:39.000000  8a858970548359cc0154883481981866
#
#    loanamount  loannumber referredby  systemloanid  termdays  totaldue  \
# 0     30000.0          12          0     301994762        30   34500.0
# 1     15000.0           2          0     301965204        30   17250.0
# 2     20000.0           7          0     301966580        15   22250.0
# 3     10000.0           3          0     301999343        15   11500.0
# 4     40000.0           9          0     301962360        30   44000.0
#
#     birthdate   ...    interest  age  avg_interest repaymentrank  \
# 0  1972-01-15   ...      4500.0   45          3900             3
# 1  1985-08-23   ...      2250.0   31             0             3
# 2  1984-09-18   ...      2250.0   32          1750             2
# 3  1977-10-10   ...      1500.0   39          2250             2
# 4  1986-09-07   ...      4000.0   30          4800             3
#
#   avginterestrank avgloanamtrank rankloanamt  rankloannum  isreffered  agerank
# 0               2              2           2            1           0        1
# 1               1              1           1            1           0        1
# 2               1              2           1            1           0        1
# 3               1              2           1            1           0        1
# 4               2              2           2            1           0        1
#
# [5 rows x 31 columns]

# %% [markdown]
# ### --- Feature Reduction - Removing unwanted feature ---

# %%
traindata.drop(['approveddate','creationdate','customerid','loanamount','loannumber','referredby',
                'systemloanid','totaldue','birthdate','longitude_gps','latitude_gps','bank_name_clients',
               'bank_branch_clients','level_of_education_clients','avg_loanamount','avg_totaldue',
                'avg_interest','avginterestrank'],axis=1, inplace=True)

# %%
traindata.drop(['interest','age'],axis=1, inplace=True)

# %%
traindata.drop(['repaymentdays'],axis=1, inplace=True)

# %%
traindata.head()
# Out:
#    termdays bank_account_type employment_status_clients good_bad_flag  \
# 0        30             Other                 Permanent          Good
# 1        30           Savings                 Permanent          Good
# 2        15             Other                 Permanent          Good
# 3        15           Savings                 Permanent          Good
# 4        30             Other                 Permanent          Good
#
#    repaymentrank  avgloanamtrank  rankloanamt  rankloannum  isreffered  \
# 0              3               2            2            1           0
# 1              3               1            1            1           0
# 2              2               2            1            1           0
# 3              2               2            1            1           0
# 4              3               2            2            1           0
#
#    agerank
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
traindata.shape
# Out:
# (4368, 10)

# %%
def getSample(size, df):
    size1 = int(round(size * 0.50))
    size2 = size - size1
    data_good = df[(df['good_bad_flag'] == 'Good')]
    data_bad = df[(df['good_bad_flag'] == 'Bad')]
    data_sample_good = data_good.sample(n=size1)
    data_sample_bad = data_bad.sample(n=size2)
    return pd.concat((data_sample_good, data_sample_bad))

# %% [markdown]
# ### Reordering to move class label at end

# %%
columns = [column for column in traindata.columns if column != 'good_bad_flag']

# %%
columns = columns + ['good_bad_flag']

# %%
traindata = traindata[columns]

# %%
traindata.head()
# Out:
#    termdays bank_account_type employment_status_clients  repaymentrank  \
# 0        30             Other                 Permanent              3
# 1        30           Savings                 Permanent              3
# 2        15             Other                 Permanent              2
# 3        15           Savings                 Permanent              2
# 4        30             Other                 Permanent              3
#
#    avgloanamtrank  rankloanamt  rankloannum  isreffered  agerank good_bad_flag
# 0               2            2            1           0        1          Good
# 1               1            1            1           0        1          Good
# 2               2            1            1           0        1          Good
# 3               2            1            1           0        1          Good
# 4               2            2            1           0        1          Good

# %%
train_600 = getSample(600, traindata)
